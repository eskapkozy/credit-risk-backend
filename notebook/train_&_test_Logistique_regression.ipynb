# %%
import pandas as pd


x_train = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_test.csv")
y_train = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_test.csv").squeeze()

x_test = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_test.csv")
y_test = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_test.csv").squeeze()

x_val = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_val.csv")
y_val = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_val.csv").squeeze()

# %% [markdown]
# # Configuration

# %%
config_path = "/configs/ressouces/Exemple_test_config.yaml"
config_train ="/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/configs/ressouces/Exemple_train_config.yaml"

# %% [markdown]
# # RUN TRAIN/VALIDATION

# %%
from src.run.logistique_regression_train_run import LogistiqueRegressionTrainRun

Train = LogistiqueRegressionTrainRun(train_map= {'x_train': x_train, 'y_train': y_train}, val_map={'x_val': x_val, 'y_val': y_val}, config_path=config_train)
# Out:
# (CVXPY) May 25 05:10:50 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.15.6755). Expected < 9.15.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 05:10:50 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.15.6755). Expected < 9.15.0. Please open a feature request on cvxpy to enable support for this version.')

# %%
Train.run()
# Out:
# 🏃 View run Logistic regression Train at: http://localhost:5000/#/experiments/1/runs/896eeb550fe24555a9a613ca983e2fcc
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# # RUN TEST

# %%
from src.run.logistique_regression_test_run import LogistiqueRegressionTestRun

test = LogistiqueRegressionTestRun(test_map={'x_test': x_test, 'y_test': y_test}, config_path=config_path)

# %%
test.run()
# Out:
# 🏃 View run Logistique Regression Test at: http://localhost:5000/#/experiments/1/runs/99a954e8a545454bbceac8ee14fc6dd3
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
