# %%
from mlflow import lightgbm

from src.run.lightgbm_train_run import LightgbmTrainRun
from src.run.lightgbm_test_run import LightgbmTestRun
import pandas as pd


x_train = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_test.csv")
y_train = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_test.csv").squeeze()

x_test = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_test.csv")
y_test = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_test.csv").squeeze()

x_val = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/x_val.csv")
y_val = pd.read_csv("/Users/macbookpro/PycharmProjects/projet_credit_risk_modeling/data/processed/splited_data/y_val.csv").squeeze()
# Out:
# (CVXPY) May 25 05:07:58 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.15.6755). Expected < 9.15.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) May 25 05:07:58 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.15.6755). Expected < 9.15.0. Please open a feature request on cvxpy to enable support for this version.')

# %% [markdown]
# # Config

# %%
train_config_path = "/configs/ressouces/Train_lightGBM_config.yaml"
test_config_path = "/configs/ressouces/Test_lightGBM_config.yaml"

# %% [markdown]
# # TRAIN/VALIDATION

# %%
lightgbmTrainRun = LightgbmTrainRun(train_map={'x_train':x_train, 'y_train':y_train},val_map={ 'x_val':x_val, 'y_val':y_val},config_path=train_config_path)

# %%
lightgbmTrainRun.run()
# Out:
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [LightGBM] [Info] Number of positive: 3732, number of negative: 3732
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 7464, number of used features: 8
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# # TEST RUN

# %%
lightgbmTestRun = LightgbmTestRun(test_map={'x_test':x_test, 'y_test':y_test},config_path=test_config_path)

# %%
lightgbmTestRun.run()
# Out:
# 🏃 View run lightgbm Test at: http://localhost:5000/#/experiments/1/runs/18fd229b05f740f38dfa48c5d7a0fe46
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
